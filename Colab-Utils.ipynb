# %% [markdown]
# <a href="https://colab.research.google.com/github/MagnificentTabby/utils/blob/main/Colab-Utils.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import ipywidgets as widgets
from google.colab import drive

drive.mount('/content/gdrive')

model_id = widgets.BoundedIntText(value=7,min=0,step=1,description='CivitAI Model ID:', disabled=False)
display(model_id)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# BoundedIntText(value=7, description='CivitAI Model ID:')

# %%
model_id = "29460"  # replace with actual model ID
url = f"https://civitai.com/api/download/models/{model_id}"

save_path = "/content/gdrive/MyDrive/sd/stable-diffusion-webui/models/Stable-diffusion/model.safetensors"

response = requests.get(url, stream=True)
response.raise_for_status()

with open(save_path, "wb") as f:
    for chunk in response.iter_content(chunk_size=8192):
        if chunk:
            f.write(chunk)

print("Download complete:", save_path)
